# %%
import torchvision
import torchvision.transforms as transforms

from google.colab import drive
drive.mount('/content/drive')
save_path = '/content/drive/My Drive/Colab Notebooks/Save/'
import os
# 创建路径如果它不存在
os.makedirs(save_path, exist_ok=True)
previous_checkpoint = None  # 用来追踪上一个checkpoint的文件名


# 准备数据集并预处理
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  #先四周填充0，在吧图像随机裁剪成32*32
    transforms.RandomHorizontalFlip(),  #图像一半的概率翻转，一半的概率不翻转
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)), #R,G,B每层的归一化用到的均值和方差
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train) #训练数据集
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)



for _, (x, y) in enumerate(trainset):
  print(x.shape, y)
  break



import torch


trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)   #生成一个个batch进行批训练，组成batch的时候顺序打乱取
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

for _, (x, y) in enumerate(trainloader):
  print(x.shape, y)
  break




import torch
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"你正在使用：{device}")
class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, ResidualBlock, num_classes=10):
        super(ResNet, self).__init__()
        self.inchannel = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  1, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 1, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 1, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 1, stride=2)
        self.fc = nn.Linear(512, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

def ResNet18():
    return ResNet(ResidualBlock)

net = ResNet18().to(device)
print(net)

# 模型权重文件路径
#model_path = 'model_epoch_X.pth'  # 替换 X 为实际的 epoch 数字

# 加载模型权重
#net.load_state_dict(torch.load(model_path))




def calc_param(model: nn.Module) -> int:
    params = list(model.parameters())
    param_size = 0
    for _param in params:
        _param_size = 1
        for _ in _param.size():
            _param_size *= _
        param_size += _param_size
    return param_size

print(f"The number of model parameters is:{calc_param(net)}")





import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay=5e-4)

# 定义学习率调度器
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5)




def load_checkpoint(model, optimizer, scheduler, filename='model_checkpoint.pth'):
    # 注意: 输入模型 & 优化器需要预先定义
    checkpoint = torch.load(filename)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    scheduler.load_state_dict(checkpoint['scheduler'])

    # 也可以加载其他数据，例如 epoch 数或损失
    epoch = checkpoint['epoch']
    loss = checkpoint['loss']

    return model, optimizer, scheduler, epoch, loss


# 例子：加载状态
checkpoint_path = os.path.join(save_path, f'model_checkpoint_43.pth')
model, optimizer, scheduler, start_epoch, val_loss = load_checkpoint(net, optimizer, scheduler, checkpoint_path)






def compute_validation_loss(model, val_loader, device):
    model.eval()  # Set the model to evaluation mode
    total_loss = 0
    total_count = 0

    with torch.no_grad():  # No gradients needed
        for x, y in val_loader:
            x, y = x.to(device), y.to(device)
            outputs = model(x)
            loss = criterion(outputs, y)
            total_loss += loss.item() * x.size(0)  # Multiply loss by batch size
            total_count += x.size(0)

    average_loss = total_loss / total_count
    return average_loss

for epoch in range(135):
    net.train()
    running_loss = 0.0
    for batch_idx, (x, y) in enumerate(trainloader, 0):
        inputs, labels = x.to(device), y.to(device)
        # 参数梯度置 0
        optimizer.zero_grad()
        # 前向推理
        outputs = net(inputs)
        # 计算损失
        loss = criterion(outputs, labels)
        # 后向传递梯度计算
        loss.backward()
        # 优化更新参数
        optimizer.step()
        running_loss += loss.item()
        if (batch_idx + 1) % 100 == 0:
            print(f"[EPOCH {epoch + 1:03} | IT {batch_idx + 1:05}] LOSS: {running_loss / batch_idx: .3f}")
    # 假设val_loss是你在验证集上计算得到的损失
    val_loss = compute_validation_loss(net, trainloader, device)
    scheduler.step(val_loss)

    # 保存模型权重、优化器和调度器状态
    # 删除上一个checkpoint
    if previous_checkpoint is not None:
        try:
            os.remove(previous_checkpoint)
            print(f"Removed previous checkpoint: {previous_checkpoint}")
        except OSError as e:
            print(f"Error: {previous_checkpoint} : {e.strerror}")

    checkpoint = {
        'epoch': epoch + 1,
        'state_dict': net.state_dict(),
        'optimizer': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
        'loss': val_loss,
    }
    checkpoint_path = os.path.join(save_path, f'model_checkpoint_{epoch+1}.pth')
    torch.save(checkpoint, checkpoint_path)
    # 更新previous_checkpoint变量
    previous_checkpoint = checkpoint_path
    print(f"Checkpoint saved at {checkpoint_path}")




def calc_acc(model: nn.Module, testloader: torch.utils.data.DataLoader) -> float:
  net.eval()
  total = 0
  correct = 0
  with torch.no_grad():
    for _, (x, y) in enumerate(testloader):
      x, y = x.to(device), y.to(device)
      outputs = model(x)
      _, predicted = torch.max(outputs.data, 1)
      total += y.size(0)
      correct += (predicted == y).sum().item()

  return correct / total


print(f"""
- 模型参数量：{calc_param(net)}
- 模型测试准确率：{calc_acc(net, testloader)}""")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 32, 32]) 6
# torch.Size([128, 3, 32, 32]) tensor([1, 1, 2, 3, 6, 6, 8, 6, 5, 5, 4, 2, 3, 5, 6, 5, 7, 0, 2, 7, 1, 8, 0, 8,
#         2, 5, 0, 9, 3, 7, 1, 4, 0, 0, 8, 2, 4, 9, 0, 1, 9, 8, 3, 9, 3, 6, 8, 4,
#         9, 7, 3, 3, 5, 8, 3, 1, 6, 3, 8, 8, 7, 4, 5, 9, 0, 7, 9, 5, 1, 4, 0, 4,
#         8, 1, 2, 2, 0, 0, 5, 4, 7, 4, 6, 6, 1, 4, 6, 5, 4, 9, 1, 1, 1, 0, 1, 2,
#         7, 9, 7, 0, 1, 1, 9, 3, 8, 6, 0, 1, 8, 0, 1, 0, 0, 9, 3, 2, 1, 2, 5, 2,
#         3, 2, 0, 1, 8, 0, 2, 3])
# 你正在使用：cuda
# ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer1): Sequential(
#     (0): ResidualBlock(
#       (left): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): ResidualBlock(
#       (left): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): ResidualBlock(
#       (left): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): ResidualBlock(
#       (left): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
# The number of model parameters is:4903242
# [EPOCH 001 | IT 00100] LOSS:  0.149
# [EPOCH 001 | IT 00200] LOSS:  0.154
# [EPOCH 001 | IT 00300] LOSS:  0.159
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_1.pth
# [EPOCH 002 | IT 00100] LOSS:  0.148
# [EPOCH 002 | IT 00200] LOSS:  0.154
# [EPOCH 002 | IT 00300] LOSS:  0.159
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_1.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_2.pth
# [EPOCH 003 | IT 00100] LOSS:  0.148
# [EPOCH 003 | IT 00200] LOSS:  0.155
# [EPOCH 003 | IT 00300] LOSS:  0.159
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_2.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_3.pth
# [EPOCH 004 | IT 00100] LOSS:  0.154
# [EPOCH 004 | IT 00200] LOSS:  0.157
# [EPOCH 004 | IT 00300] LOSS:  0.159
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_3.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_4.pth
# [EPOCH 005 | IT 00100] LOSS:  0.145
# [EPOCH 005 | IT 00200] LOSS:  0.146
# [EPOCH 005 | IT 00300] LOSS:  0.152
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_4.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_5.pth
# [EPOCH 006 | IT 00100] LOSS:  0.150
# [EPOCH 006 | IT 00200] LOSS:  0.151
# [EPOCH 006 | IT 00300] LOSS:  0.153
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_5.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_6.pth
# [EPOCH 007 | IT 00100] LOSS:  0.137
# [EPOCH 007 | IT 00200] LOSS:  0.145
# [EPOCH 007 | IT 00300] LOSS:  0.152
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_6.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_7.pth
# [EPOCH 008 | IT 00100] LOSS:  0.139
# [EPOCH 008 | IT 00200] LOSS:  0.144
# [EPOCH 008 | IT 00300] LOSS:  0.148
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_7.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_8.pth
# [EPOCH 009 | IT 00100] LOSS:  0.143
# [EPOCH 009 | IT 00200] LOSS:  0.147
# [EPOCH 009 | IT 00300] LOSS:  0.154
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_8.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_9.pth
# [EPOCH 010 | IT 00100] LOSS:  0.134
# [EPOCH 010 | IT 00200] LOSS:  0.141
# [EPOCH 010 | IT 00300] LOSS:  0.143
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_9.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_10.pth
# [EPOCH 011 | IT 00100] LOSS:  0.142
# [EPOCH 011 | IT 00200] LOSS:  0.144
# [EPOCH 011 | IT 00300] LOSS:  0.149
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_10.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_11.pth
# [EPOCH 012 | IT 00100] LOSS:  0.140
# [EPOCH 012 | IT 00200] LOSS:  0.143
# [EPOCH 012 | IT 00300] LOSS:  0.143
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_11.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_12.pth
# [EPOCH 013 | IT 00100] LOSS:  0.145
# [EPOCH 013 | IT 00200] LOSS:  0.146
# [EPOCH 013 | IT 00300] LOSS:  0.150
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_12.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_13.pth
# [EPOCH 014 | IT 00100] LOSS:  0.141
# [EPOCH 014 | IT 00200] LOSS:  0.146
# [EPOCH 014 | IT 00300] LOSS:  0.144
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_13.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_14.pth
# [EPOCH 015 | IT 00100] LOSS:  0.116
# [EPOCH 015 | IT 00200] LOSS:  0.109
# [EPOCH 015 | IT 00300] LOSS:  0.105
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_14.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_15.pth
# [EPOCH 016 | IT 00100] LOSS:  0.089
# [EPOCH 016 | IT 00200] LOSS:  0.089
# [EPOCH 016 | IT 00300] LOSS:  0.090
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_15.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_16.pth
# [EPOCH 017 | IT 00100] LOSS:  0.081
# [EPOCH 017 | IT 00200] LOSS:  0.082
# [EPOCH 017 | IT 00300] LOSS:  0.083
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_16.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_17.pth
# [EPOCH 018 | IT 00100] LOSS:  0.076
# [EPOCH 018 | IT 00200] LOSS:  0.080
# [EPOCH 018 | IT 00300] LOSS:  0.082
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_17.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_18.pth
# [EPOCH 019 | IT 00100] LOSS:  0.081
# [EPOCH 019 | IT 00200] LOSS:  0.080
# [EPOCH 019 | IT 00300] LOSS:  0.081
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_18.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_19.pth
# [EPOCH 020 | IT 00100] LOSS:  0.075
# [EPOCH 020 | IT 00200] LOSS:  0.077
# [EPOCH 020 | IT 00300] LOSS:  0.077
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_19.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_20.pth
# [EPOCH 021 | IT 00100] LOSS:  0.069
# [EPOCH 021 | IT 00200] LOSS:  0.071
# [EPOCH 021 | IT 00300] LOSS:  0.074
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_20.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_21.pth
# [EPOCH 022 | IT 00100] LOSS:  0.076
# [EPOCH 022 | IT 00200] LOSS:  0.073
# [EPOCH 022 | IT 00300] LOSS:  0.075
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_21.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_22.pth
# [EPOCH 023 | IT 00100] LOSS:  0.071
# [EPOCH 023 | IT 00200] LOSS:  0.076
# [EPOCH 023 | IT 00300] LOSS:  0.077
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_22.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_23.pth
# [EPOCH 024 | IT 00100] LOSS:  0.075
# [EPOCH 024 | IT 00200] LOSS:  0.072
# [EPOCH 024 | IT 00300] LOSS:  0.072
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_23.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_24.pth
# [EPOCH 025 | IT 00100] LOSS:  0.074
# [EPOCH 025 | IT 00200] LOSS:  0.071
# [EPOCH 025 | IT 00300] LOSS:  0.073
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_24.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_25.pth
# [EPOCH 026 | IT 00100] LOSS:  0.070
# [EPOCH 026 | IT 00200] LOSS:  0.071
# [EPOCH 026 | IT 00300] LOSS:  0.071
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_25.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_26.pth
# [EPOCH 027 | IT 00100] LOSS:  0.068
# [EPOCH 027 | IT 00200] LOSS:  0.070
# [EPOCH 027 | IT 00300] LOSS:  0.071
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_26.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_27.pth
# [EPOCH 028 | IT 00100] LOSS:  0.062
# [EPOCH 028 | IT 00200] LOSS:  0.064
# [EPOCH 028 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_27.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_28.pth
# [EPOCH 029 | IT 00100] LOSS:  0.069
# [EPOCH 029 | IT 00200] LOSS:  0.069
# [EPOCH 029 | IT 00300] LOSS:  0.070
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_28.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_29.pth
# [EPOCH 030 | IT 00100] LOSS:  0.067
# [EPOCH 030 | IT 00200] LOSS:  0.067
# [EPOCH 030 | IT 00300] LOSS:  0.069
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_29.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_30.pth
# [EPOCH 031 | IT 00100] LOSS:  0.065
# [EPOCH 031 | IT 00200] LOSS:  0.064
# [EPOCH 031 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_30.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_31.pth
# [EPOCH 032 | IT 00100] LOSS:  0.067
# [EPOCH 032 | IT 00200] LOSS:  0.069
# [EPOCH 032 | IT 00300] LOSS:  0.071
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_31.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_32.pth
# [EPOCH 033 | IT 00100] LOSS:  0.067
# [EPOCH 033 | IT 00200] LOSS:  0.069
# [EPOCH 033 | IT 00300] LOSS:  0.070
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_32.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_33.pth
# [EPOCH 034 | IT 00100] LOSS:  0.069
# [EPOCH 034 | IT 00200] LOSS:  0.067
# [EPOCH 034 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_33.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_34.pth
# [EPOCH 035 | IT 00100] LOSS:  0.059
# [EPOCH 035 | IT 00200] LOSS:  0.062
# [EPOCH 035 | IT 00300] LOSS:  0.066
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_34.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_35.pth
# [EPOCH 036 | IT 00100] LOSS:  0.066
# [EPOCH 036 | IT 00200] LOSS:  0.064
# [EPOCH 036 | IT 00300] LOSS:  0.064
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_35.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_36.pth
# [EPOCH 037 | IT 00100] LOSS:  0.062
# [EPOCH 037 | IT 00200] LOSS:  0.061
# [EPOCH 037 | IT 00300] LOSS:  0.065
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_36.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_37.pth
# [EPOCH 038 | IT 00100] LOSS:  0.068
# [EPOCH 038 | IT 00200] LOSS:  0.067
# [EPOCH 038 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_37.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_38.pth
# [EPOCH 039 | IT 00100] LOSS:  0.066
# [EPOCH 039 | IT 00200] LOSS:  0.068
# [EPOCH 039 | IT 00300] LOSS:  0.069
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_38.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_39.pth
# [EPOCH 040 | IT 00100] LOSS:  0.064
# [EPOCH 040 | IT 00200] LOSS:  0.065
# [EPOCH 040 | IT 00300] LOSS:  0.065
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_39.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_40.pth
# [EPOCH 041 | IT 00100] LOSS:  0.069
# [EPOCH 041 | IT 00200] LOSS:  0.068
# [EPOCH 041 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_40.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_41.pth
# [EPOCH 042 | IT 00100] LOSS:  0.069
# [EPOCH 042 | IT 00200] LOSS:  0.066
# [EPOCH 042 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_41.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_42.pth
# [EPOCH 043 | IT 00100] LOSS:  0.059
# [EPOCH 043 | IT 00200] LOSS:  0.063
# [EPOCH 043 | IT 00300] LOSS:  0.065
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_42.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_43.pth
# [EPOCH 044 | IT 00100] LOSS:  0.065
# [EPOCH 044 | IT 00200] LOSS:  0.066
# [EPOCH 044 | IT 00300] LOSS:  0.068
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_43.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_44.pth
# [EPOCH 045 | IT 00100] LOSS:  0.050
# [EPOCH 045 | IT 00200] LOSS:  0.049
# [EPOCH 045 | IT 00300] LOSS:  0.048
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_44.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_45.pth
# [EPOCH 046 | IT 00100] LOSS:  0.036
# [EPOCH 046 | IT 00200] LOSS:  0.037
# [EPOCH 046 | IT 00300] LOSS:  0.036
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_45.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_46.pth
# [EPOCH 047 | IT 00100] LOSS:  0.033
# [EPOCH 047 | IT 00200] LOSS:  0.034
# [EPOCH 047 | IT 00300] LOSS:  0.035
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_46.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_47.pth
# [EPOCH 048 | IT 00100] LOSS:  0.034
# [EPOCH 048 | IT 00200] LOSS:  0.033
# [EPOCH 048 | IT 00300] LOSS:  0.034
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_47.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_48.pth
# [EPOCH 049 | IT 00100] LOSS:  0.033
# [EPOCH 049 | IT 00200] LOSS:  0.032
# [EPOCH 049 | IT 00300] LOSS:  0.033
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_48.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_49.pth
# [EPOCH 050 | IT 00100] LOSS:  0.033
# [EPOCH 050 | IT 00200] LOSS:  0.033
# [EPOCH 050 | IT 00300] LOSS:  0.033
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_49.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_50.pth
# [EPOCH 051 | IT 00100] LOSS:  0.029
# [EPOCH 051 | IT 00200] LOSS:  0.030
# [EPOCH 051 | IT 00300] LOSS:  0.034
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_50.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_51.pth
# [EPOCH 052 | IT 00100] LOSS:  0.034
# [EPOCH 052 | IT 00200] LOSS:  0.034
# [EPOCH 052 | IT 00300] LOSS:  0.034
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_51.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_52.pth
# [EPOCH 053 | IT 00100] LOSS:  0.031
# [EPOCH 053 | IT 00200] LOSS:  0.032
# [EPOCH 053 | IT 00300] LOSS:  0.032
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_52.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_53.pth
# [EPOCH 054 | IT 00100] LOSS:  0.032
# [EPOCH 054 | IT 00200] LOSS:  0.031
# [EPOCH 054 | IT 00300] LOSS:  0.032
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_53.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_54.pth
# [EPOCH 055 | IT 00100] LOSS:  0.030
# [EPOCH 055 | IT 00200] LOSS:  0.030
# [EPOCH 055 | IT 00300] LOSS:  0.031
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_54.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_55.pth
# [EPOCH 056 | IT 00100] LOSS:  0.032
# [EPOCH 056 | IT 00200] LOSS:  0.031
# [EPOCH 056 | IT 00300] LOSS:  0.031
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_55.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_56.pth
# [EPOCH 057 | IT 00100] LOSS:  0.029
# [EPOCH 057 | IT 00200] LOSS:  0.029
# [EPOCH 057 | IT 00300] LOSS:  0.029
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_56.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_57.pth
# [EPOCH 058 | IT 00100] LOSS:  0.027
# [EPOCH 058 | IT 00200] LOSS:  0.025
# [EPOCH 058 | IT 00300] LOSS:  0.025
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_57.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_58.pth
# [EPOCH 059 | IT 00100] LOSS:  0.020
# [EPOCH 059 | IT 00200] LOSS:  0.020
# [EPOCH 059 | IT 00300] LOSS:  0.020
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_58.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_59.pth
# [EPOCH 060 | IT 00100] LOSS:  0.020
# [EPOCH 060 | IT 00200] LOSS:  0.020
# [EPOCH 060 | IT 00300] LOSS:  0.019
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_59.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_60.pth
# [EPOCH 061 | IT 00100] LOSS:  0.018
# [EPOCH 061 | IT 00200] LOSS:  0.018
# [EPOCH 061 | IT 00300] LOSS:  0.018
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_60.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_61.pth
# [EPOCH 062 | IT 00100] LOSS:  0.017
# [EPOCH 062 | IT 00200] LOSS:  0.018
# [EPOCH 062 | IT 00300] LOSS:  0.019
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_61.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_62.pth
# [EPOCH 063 | IT 00100] LOSS:  0.017
# [EPOCH 063 | IT 00200] LOSS:  0.018
# [EPOCH 063 | IT 00300] LOSS:  0.018
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_62.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_63.pth
# [EPOCH 064 | IT 00100] LOSS:  0.017
# [EPOCH 064 | IT 00200] LOSS:  0.017
# [EPOCH 064 | IT 00300] LOSS:  0.017
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_63.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_64.pth
# [EPOCH 065 | IT 00100] LOSS:  0.019
# [EPOCH 065 | IT 00200] LOSS:  0.019
# [EPOCH 065 | IT 00300] LOSS:  0.019
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_64.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_65.pth
# [EPOCH 066 | IT 00100] LOSS:  0.019
# [EPOCH 066 | IT 00200] LOSS:  0.018
# [EPOCH 066 | IT 00300] LOSS:  0.019
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_65.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_66.pth
# [EPOCH 067 | IT 00100] LOSS:  0.017
# [EPOCH 067 | IT 00200] LOSS:  0.018
# [EPOCH 067 | IT 00300] LOSS:  0.018
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_66.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_67.pth
# [EPOCH 068 | IT 00100] LOSS:  0.015
# [EPOCH 068 | IT 00200] LOSS:  0.016
# [EPOCH 068 | IT 00300] LOSS:  0.017
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_67.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_68.pth
# [EPOCH 069 | IT 00100] LOSS:  0.017
# [EPOCH 069 | IT 00200] LOSS:  0.017
# [EPOCH 069 | IT 00300] LOSS:  0.017
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_68.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_69.pth
# [EPOCH 070 | IT 00100] LOSS:  0.015
# [EPOCH 070 | IT 00200] LOSS:  0.017
# [EPOCH 070 | IT 00300] LOSS:  0.017
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_69.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_70.pth
# [EPOCH 071 | IT 00100] LOSS:  0.018
# [EPOCH 071 | IT 00200] LOSS:  0.018
# [EPOCH 071 | IT 00300] LOSS:  0.018
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_70.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_71.pth
# [EPOCH 072 | IT 00100] LOSS:  0.018
# [EPOCH 072 | IT 00200] LOSS:  0.017
# [EPOCH 072 | IT 00300] LOSS:  0.017
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_71.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_72.pth
# [EPOCH 073 | IT 00100] LOSS:  0.017
# [EPOCH 073 | IT 00200] LOSS:  0.017
# [EPOCH 073 | IT 00300] LOSS:  0.017
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_72.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_73.pth
# [EPOCH 074 | IT 00100] LOSS:  0.018
# [EPOCH 074 | IT 00200] LOSS:  0.018
# [EPOCH 074 | IT 00300] LOSS:  0.018
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_73.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_74.pth
# [EPOCH 075 | IT 00100] LOSS:  0.015
# [EPOCH 075 | IT 00200] LOSS:  0.016
# [EPOCH 075 | IT 00300] LOSS:  0.016
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_74.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_75.pth
# [EPOCH 076 | IT 00100] LOSS:  0.018
# [EPOCH 076 | IT 00200] LOSS:  0.017
# [EPOCH 076 | IT 00300] LOSS:  0.016
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_75.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_76.pth
# [EPOCH 077 | IT 00100] LOSS:  0.014
# [EPOCH 077 | IT 00200] LOSS:  0.015
# [EPOCH 077 | IT 00300] LOSS:  0.015
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_76.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_77.pth
# [EPOCH 078 | IT 00100] LOSS:  0.017
# [EPOCH 078 | IT 00200] LOSS:  0.016
# [EPOCH 078 | IT 00300] LOSS:  0.016
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_77.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_78.pth
# [EPOCH 079 | IT 00100] LOSS:  0.016
# [EPOCH 079 | IT 00200] LOSS:  0.015
# [EPOCH 079 | IT 00300] LOSS:  0.015
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_78.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_79.pth
# [EPOCH 080 | IT 00100] LOSS:  0.014
# [EPOCH 080 | IT 00200] LOSS:  0.015
# [EPOCH 080 | IT 00300] LOSS:  0.016
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_79.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_80.pth
# [EPOCH 081 | IT 00100] LOSS:  0.016
# [EPOCH 081 | IT 00200] LOSS:  0.015
# [EPOCH 081 | IT 00300] LOSS:  0.016
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_80.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_81.pth
# [EPOCH 082 | IT 00100] LOSS:  0.016
# [EPOCH 082 | IT 00200] LOSS:  0.016
# [EPOCH 082 | IT 00300] LOSS:  0.016
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_81.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_82.pth
# [EPOCH 083 | IT 00100] LOSS:  0.015
# [EPOCH 083 | IT 00200] LOSS:  0.014
# [EPOCH 083 | IT 00300] LOSS:  0.014
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_82.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_83.pth
# [EPOCH 084 | IT 00100] LOSS:  0.013
# [EPOCH 084 | IT 00200] LOSS:  0.013
# [EPOCH 084 | IT 00300] LOSS:  0.013
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_83.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_84.pth
# [EPOCH 085 | IT 00100] LOSS:  0.012
# [EPOCH 085 | IT 00200] LOSS:  0.011
# [EPOCH 085 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_84.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_85.pth
# [EPOCH 086 | IT 00100] LOSS:  0.013
# [EPOCH 086 | IT 00200] LOSS:  0.012
# [EPOCH 086 | IT 00300] LOSS:  0.013
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_85.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_86.pth
# [EPOCH 087 | IT 00100] LOSS:  0.013
# [EPOCH 087 | IT 00200] LOSS:  0.012
# [EPOCH 087 | IT 00300] LOSS:  0.012
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_86.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_87.pth
# [EPOCH 088 | IT 00100] LOSS:  0.011
# [EPOCH 088 | IT 00200] LOSS:  0.011
# [EPOCH 088 | IT 00300] LOSS:  0.012
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_87.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_88.pth
# [EPOCH 089 | IT 00100] LOSS:  0.011
# [EPOCH 089 | IT 00200] LOSS:  0.011
# [EPOCH 089 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_88.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_89.pth
# [EPOCH 090 | IT 00100] LOSS:  0.011
# [EPOCH 090 | IT 00200] LOSS:  0.011
# [EPOCH 090 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_89.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_90.pth
# [EPOCH 091 | IT 00100] LOSS:  0.011
# [EPOCH 091 | IT 00200] LOSS:  0.011
# [EPOCH 091 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_90.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_91.pth
# [EPOCH 092 | IT 00100] LOSS:  0.010
# [EPOCH 092 | IT 00200] LOSS:  0.010
# [EPOCH 092 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_91.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_92.pth
# [EPOCH 093 | IT 00100] LOSS:  0.010
# [EPOCH 093 | IT 00200] LOSS:  0.011
# [EPOCH 093 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_92.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_93.pth
# [EPOCH 094 | IT 00100] LOSS:  0.010
# [EPOCH 094 | IT 00200] LOSS:  0.011
# [EPOCH 094 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_93.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_94.pth
# [EPOCH 095 | IT 00100] LOSS:  0.011
# [EPOCH 095 | IT 00200] LOSS:  0.011
# [EPOCH 095 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_94.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_95.pth
# [EPOCH 096 | IT 00100] LOSS:  0.011
# [EPOCH 096 | IT 00200] LOSS:  0.011
# [EPOCH 096 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_95.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_96.pth
# [EPOCH 097 | IT 00100] LOSS:  0.012
# [EPOCH 097 | IT 00200] LOSS:  0.011
# [EPOCH 097 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_96.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_97.pth
# [EPOCH 098 | IT 00100] LOSS:  0.009
# [EPOCH 098 | IT 00200] LOSS:  0.010
# [EPOCH 098 | IT 00300] LOSS:  0.010
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_97.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_98.pth
# [EPOCH 099 | IT 00100] LOSS:  0.010
# [EPOCH 099 | IT 00200] LOSS:  0.010
# [EPOCH 099 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_98.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_99.pth
# [EPOCH 100 | IT 00100] LOSS:  0.010
# [EPOCH 100 | IT 00200] LOSS:  0.011
# [EPOCH 100 | IT 00300] LOSS:  0.010
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_99.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_100.pth
# [EPOCH 101 | IT 00100] LOSS:  0.010
# [EPOCH 101 | IT 00200] LOSS:  0.010
# [EPOCH 101 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_100.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_101.pth
# [EPOCH 102 | IT 00100] LOSS:  0.012
# [EPOCH 102 | IT 00200] LOSS:  0.012
# [EPOCH 102 | IT 00300] LOSS:  0.012
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_101.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_102.pth
# [EPOCH 103 | IT 00100] LOSS:  0.011
# [EPOCH 103 | IT 00200] LOSS:  0.010
# [EPOCH 103 | IT 00300] LOSS:  0.011
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_102.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_103.pth
# [EPOCH 104 | IT 00100] LOSS:  0.010
# [EPOCH 104 | IT 00200] LOSS:  0.010
# [EPOCH 104 | IT 00300] LOSS:  0.010
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_103.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_104.pth
# [EPOCH 105 | IT 00100] LOSS:  0.009
# [EPOCH 105 | IT 00200] LOSS:  0.009
# [EPOCH 105 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_104.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_105.pth
# [EPOCH 106 | IT 00100] LOSS:  0.008
# [EPOCH 106 | IT 00200] LOSS:  0.009
# [EPOCH 106 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_105.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_106.pth
# [EPOCH 107 | IT 00100] LOSS:  0.009
# [EPOCH 107 | IT 00200] LOSS:  0.009
# [EPOCH 107 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_106.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_107.pth
# [EPOCH 108 | IT 00100] LOSS:  0.009
# [EPOCH 108 | IT 00200] LOSS:  0.008
# [EPOCH 108 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_107.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_108.pth
# [EPOCH 109 | IT 00100] LOSS:  0.008
# [EPOCH 109 | IT 00200] LOSS:  0.009
# [EPOCH 109 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_108.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_109.pth
# [EPOCH 110 | IT 00100] LOSS:  0.009
# [EPOCH 110 | IT 00200] LOSS:  0.009
# [EPOCH 110 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_109.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_110.pth
# [EPOCH 111 | IT 00100] LOSS:  0.009
# [EPOCH 111 | IT 00200] LOSS:  0.009
# [EPOCH 111 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_110.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_111.pth
# [EPOCH 112 | IT 00100] LOSS:  0.008
# [EPOCH 112 | IT 00200] LOSS:  0.008
# [EPOCH 112 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_111.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_112.pth
# [EPOCH 113 | IT 00100] LOSS:  0.008
# [EPOCH 113 | IT 00200] LOSS:  0.008
# [EPOCH 113 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_112.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_113.pth
# [EPOCH 114 | IT 00100] LOSS:  0.009
# [EPOCH 114 | IT 00200] LOSS:  0.009
# [EPOCH 114 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_113.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_114.pth
# [EPOCH 115 | IT 00100] LOSS:  0.008
# [EPOCH 115 | IT 00200] LOSS:  0.008
# [EPOCH 115 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_114.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_115.pth
# [EPOCH 116 | IT 00100] LOSS:  0.009
# [EPOCH 116 | IT 00200] LOSS:  0.009
# [EPOCH 116 | IT 00300] LOSS:  0.009
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_115.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_116.pth
# [EPOCH 117 | IT 00100] LOSS:  0.008
# [EPOCH 117 | IT 00200] LOSS:  0.008
# [EPOCH 117 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_116.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_117.pth
# [EPOCH 118 | IT 00100] LOSS:  0.008
# [EPOCH 118 | IT 00200] LOSS:  0.008
# [EPOCH 118 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_117.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_118.pth
# [EPOCH 119 | IT 00100] LOSS:  0.008
# [EPOCH 119 | IT 00200] LOSS:  0.008
# [EPOCH 119 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_118.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_119.pth
# [EPOCH 120 | IT 00100] LOSS:  0.008
# [EPOCH 120 | IT 00200] LOSS:  0.008
# [EPOCH 120 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_119.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_120.pth
# [EPOCH 121 | IT 00100] LOSS:  0.008
# [EPOCH 121 | IT 00200] LOSS:  0.008
# [EPOCH 121 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_120.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_121.pth
# [EPOCH 122 | IT 00100] LOSS:  0.007
# [EPOCH 122 | IT 00200] LOSS:  0.008
# [EPOCH 122 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_121.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_122.pth
# [EPOCH 123 | IT 00100] LOSS:  0.008
# [EPOCH 123 | IT 00200] LOSS:  0.008
# [EPOCH 123 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_122.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_123.pth
# [EPOCH 124 | IT 00100] LOSS:  0.008
# [EPOCH 124 | IT 00200] LOSS:  0.008
# [EPOCH 124 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_123.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_124.pth
# [EPOCH 125 | IT 00100] LOSS:  0.007
# [EPOCH 125 | IT 00200] LOSS:  0.008
# [EPOCH 125 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_124.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_125.pth
# [EPOCH 126 | IT 00100] LOSS:  0.008
# [EPOCH 126 | IT 00200] LOSS:  0.007
# [EPOCH 126 | IT 00300] LOSS:  0.007
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_125.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_126.pth
# [EPOCH 127 | IT 00100] LOSS:  0.008
# [EPOCH 127 | IT 00200] LOSS:  0.008
# [EPOCH 127 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_126.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_127.pth
# [EPOCH 128 | IT 00100] LOSS:  0.008
# [EPOCH 128 | IT 00200] LOSS:  0.008
# [EPOCH 128 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_127.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_128.pth
# [EPOCH 129 | IT 00100] LOSS:  0.007
# [EPOCH 129 | IT 00200] LOSS:  0.007
# [EPOCH 129 | IT 00300] LOSS:  0.007
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_128.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_129.pth
# [EPOCH 130 | IT 00100] LOSS:  0.008
# [EPOCH 130 | IT 00200] LOSS:  0.007
# [EPOCH 130 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_129.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_130.pth
# [EPOCH 131 | IT 00100] LOSS:  0.007
# [EPOCH 131 | IT 00200] LOSS:  0.007
# [EPOCH 131 | IT 00300] LOSS:  0.007
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_130.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_131.pth
# [EPOCH 132 | IT 00100] LOSS:  0.008
# [EPOCH 132 | IT 00200] LOSS:  0.008
# [EPOCH 132 | IT 00300] LOSS:  0.007
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_131.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_132.pth
# [EPOCH 133 | IT 00100] LOSS:  0.007
# [EPOCH 133 | IT 00200] LOSS:  0.007
# [EPOCH 133 | IT 00300] LOSS:  0.007
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_132.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_133.pth
# [EPOCH 134 | IT 00100] LOSS:  0.007
# [EPOCH 134 | IT 00200] LOSS:  0.007
# [EPOCH 134 | IT 00300] LOSS:  0.007
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_133.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_134.pth
# [EPOCH 135 | IT 00100] LOSS:  0.007
# [EPOCH 135 | IT 00200] LOSS:  0.007
# [EPOCH 135 | IT 00300] LOSS:  0.008
# Removed previous checkpoint: /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_134.pth
# Checkpoint saved at /content/drive/My Drive/Colab Notebooks/Save/model_checkpoint_135.pth
#
# - 模型参数量：4903242
# - 模型测试准确率：0.9208
